# %%
import pandas as pd

# %%
import csv
with open('E:\\car.data','r')as f:
      car_data=csv.reader(f,delimiter='\n')
      for i in car_data:
          print(i)
# Out:
# ['vhigh,vhigh,2,2,small,low,unacc']
# ['vhigh,vhigh,2,2,small,med,unacc']
# ['vhigh,vhigh,2,2,small,high,unacc']
# ['vhigh,vhigh,2,2,med,low,unacc']
# ['vhigh,vhigh,2,2,med,med,unacc']
# ['vhigh,vhigh,2,2,med,high,unacc']
# ['vhigh,vhigh,2,2,big,low,unacc']
# ['vhigh,vhigh,2,2,big,med,unacc']
# ['vhigh,vhigh,2,2,big,high,unacc']
# ['vhigh,vhigh,2,4,small,low,unacc']
# ['vhigh,vhigh,2,4,small,med,unacc']
# ['vhigh,vhigh,2,4,small,high,unacc']
# ['vhigh,vhigh,2,4,med,low,unacc']
# ['vhigh,vhigh,2,4,med,med,unacc']
# ['vhigh,vhigh,2,4,med,high,unacc']
# ['vhigh,vhigh,2,4,big,low,unacc']
# ['vhigh,vhigh,2,4,big,med,unacc']
# ['vhigh,vhigh,2,4,big,high,unacc']
# ['vhigh,vhigh,2,more,small,low,unacc']
# ['vhigh,vhigh,2,more,small,med,unacc']
# ['vhigh,vhigh,2,more,small,high,unacc']
# ['vhigh,vhigh,2,more,med,low,unacc']
# ['vhigh,vhigh,2,more,med,med,unacc']
# ['vhigh,vhigh,2,more,med,high,unacc']
# ['vhigh,vhigh,2,more,big,low,unacc']
# ['vhigh,vhigh,2,more,big,med,unacc']
# ...

# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host="localhost",user="root",passwd="munai1234")

# %%
mydb

# %%
cursor = mydb.cursor()

# %%
cursor.execute("create database cardataset70")

# %%
cursor.execute('create table cardataset70.car5(buying VARCHAR(30) ,maint VARCHAR(30)  ,doors VARCHAR(10) ,persons VARCHAR(30) ,lug_boot VARCHAR(30),safety VARCHAR(30),model varchar(30))')

# %%
cursor.execute('use  cardataset70')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('car5',)]

# %%
import csv

with open('E:\\car.data', 'r') as f:
    data = csv.reader(f, delimiter='\n')
    for row in data:
        lst = row[0].split(',')
        cursor.execute("INSERT INTO cardataset70.car5 values ('{0}', '{1}', '{2}', '{3}','{4}', '{5}', '{6}' )".format(lst[0], lst[1], lst[2], lst[3], lst[4], lst[5], lst[6]))

# %%
cursor.execute('select count(*) from cardataset70.car5')

# %%
cursor.fetchall()
# Out:
# [(1728,)]

# %%
cursor.execute('select * from cardataset70.car5')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute('select buying,count(*) from cardataset70.car5 group by buying')
cursor.fetchall()
# Out:
# [('vhigh', 432), ('high', 432), ('med', 432), ('low', 432)]

# %%
cursor.execute('select * from cardataset70.car5 where doors=4')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %%
query = "SELECT * FROM cardataset70.car5 WHERE doors = '8'"
cursor.execute(query)
cursor.fetchall()
# Out:
# []

# %%
query = "SELECT doors, count(*) FROM cardataset70.car5 GROUP BY doors"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('2', 432), ('3', 432), ('4', 432), ('5more', 432)]

# %%
query = "UPDATE cardataset70.car5 SET doors = '8' WHERE doors = '2'"
cursor.execute(query)
mydb.commit()

# %%
query = "SELECT doors, count(*) FROM cardataset70.car5 GROUP BY doors"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('8', 432), ('3', 432), ('4', 432), ('5more', 432)]

# %%
query = "DROP TABLE cardataset70.car5"
cursor.execute(query)
mydb.commit()

# %%
query = "SHOW TABLES"
cursor.execute(query)
cursor.fetchall()
# Out:
# []

# %%
query = "SHOW DATABASES"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('cardataset70',),
#  ('cardataset90',),
#  ('cardatasets',),
#  ('cardatasets1',),
#  ('cardatasets6',),
#  ('information_schema',),
#  ('munai',),
#  ('munai1',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testmunai',),
#  ('testsudhineuron',),
#  ('testsudhineuron1',),
#  ('world',)]

# %%
query = "DROP DATABASE cardataset70"
cursor.execute(query)
mydb.commit()

# %%
query = "SHOW DATABASES"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('cardataset90',),
#  ('cardatasets',),
#  ('cardatasets1',),
#  ('cardatasets6',),
#  ('information_schema',),
#  ('munai',),
#  ('munai1',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testmunai',),
#  ('testsudhineuron',),
#  ('testsudhineuron1',),
#  ('world',)]
